# %% [markdown]
# <a href="https://colab.research.google.com/github/wesslen/llm-experiments/blob/main/notebooks/nondeterminism/structured_data/llama3_1_8b_pydantic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Llama 3.1 8B Instruct with Pydantic Non-Determinism Experiment Analysis
#
# ## Experiment Overview
# * Tests Llama 3.1 8B Instruct's output consistency with structured JSON responses
# * This run uses Pydantic with LangChain for structured data generation.
# * Uses three different prompt types:
#   - Exercise benefits (descriptive/analytical)
#   - Random numbers (explicit randomness)
#   - Major cities (factual)
# * Runs 20 iterations per prompt
# * Measures variation using entropy scores and unique response counts
#
# ## Hypothesis
# * Exercise benefits: Expected moderate variation (entropy ~1.0-1.5)
# * Random numbers: Expected high variation (entropy ~2.0-2.5)
# * City names: Expected low variation (entropy ~0.5-1.0)
#
# ## Results Analysis
# * Exercise Benefits
#   - Moderate success rate (65%) with 13 successful responses out of 20 attempts
#   - High entropy across all fields (2.565, 2.458, 2.565)
#   - Consistent with previous pattern of high variation in descriptive content
#   - Shows detailed, well-formed responses for successful attempts
#   - All three benefits show similar levels of variation/uniqueness
#
# * Random Numbers
#   - Complete failure (0% success rate) with all 20 attempts failing
#   - All errors categorized as "other_error" suggesting systematic formatting issues
#   - Unable to analyze entropy or variation due to no successful responses
#   - Suggests need for improved prompt engineering for numerical responses
#
# * Cities
#   - Complete failure (0% success rate) with all 20 attempts failing
#   - All errors categorized as "other_error" like the numbers experiment
#   - Unable to analyze entropy or variation due to no successful responses
#   - Indicates potential issues with the model handling structured outputs for simpler tasks
#
# Key Finding: The model shows better capability with complex descriptive tasks (exercise benefits) than with simpler structured tasks (numbers and cities), suggesting that the current prompt structure may need refinement for basic list-type responses. The exercise prompt's success indicates the model can handle structured output when properly guided.

# %%
# !uv pip install --system openai langchain langchain_core langchain_openai
# Out:
# Using Python 3.10.12 environment at /usr
# Resolved 45 packages in 1.03s
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# langchain-openai ------------------------------     0 B/49.20 KiB
# ⠙ Preparing packages... (0/2)
# langchain-openai ------------------------------ 14.09 KiB/49.20 KiB
# ⠙ Preparing packages... (0/2)
# langchain-openai ------------------------------ 14.09 KiB/49.20 KiB
# ⠙ Preparing packages... (0/2)
# langchain-openai ------------------------------ 14.09 KiB/49.20 KiB
# ⠙ Preparing packages... (0/2)
# langchain-openai ------------------------------ 14.09 KiB/49.20 KiB
# ⠙ Preparing packages... (0/2)
# langchain-openai ------------------------------ 14.09 KiB/49.20 KiB
# ⠙ Preparing packages... (0/2)
# langchain-openai ------------------------------ 30.09 KiB/49.20 KiB
# ⠙ Preparing packages... (0/2)
# langchain-openai ------------------------------ 30.09 KiB/49.20 KiB
# ⠙ Preparing packages... (0/2)
# langchain-openai ------------------------------ 46.09 KiB/49.20 KiB
# ⠙ Preparing packages... (0/2)
# Prepared 2 packages in 89ms
# Installed 2 packages in 1ms
#  + langchain-openai==0.2.9
#  + tiktoken==0.8.0

# %%
import os
from google.colab import userdata
os.environ["OPENAI_API_KEY"] = userdata.get('DSBA_LLAMA3_KEY')
os.environ["BASE_URL"] = userdata.get('MODAL_BASE_URL')
os.environ["model"] = "/models/NousResearch/Meta-Llama-3.1-8B-Instruct"

# %%
from pydantic import BaseModel, Field, field_validator, ValidationError
from typing import List, Dict, Optional
from langchain_openai import ChatOpenAI
from langchain.output_parsers import PydanticOutputParser
from langchain_core.prompts import PromptTemplate
import statistics
import datetime
from collections import defaultdict
import numpy as np
from scipy.stats import entropy
import os
from pathlib import Path
import json

# Add an Error Tracking Model
class ExperimentResult(BaseModel):
    """Track both successful and failed responses"""
    success: bool
    data: Optional[dict] = None
    error_type: Optional[str] = None
    error_detail: Optional[str] = None
    raw_response: Optional[str] = None

# Pydantic models for structured outputs
class ExerciseBenefits(BaseModel):
    """Structured format for exercise benefits"""
    benefit1: str = Field(
        description="A key physical health benefit of exercise",
        min_length=10,
        max_length=200
    )
    benefit2: str = Field(
        description="A key mental health benefit of exercise",
        min_length=10,
        max_length=200
    )
    benefit3: str = Field(
        description="A key energy or lifestyle benefit of exercise",
        min_length=10,
        max_length=200
    )

    @field_validator('benefit2')
    def must_mention_mental_health(cls, v):
        if 'mental' not in v.lower():
            raise ValueError('benefit2 must mention mental health')
        return v

class RandomNumbers(BaseModel):
    """Structured format for random numbers"""
    num1: int = Field(
        description="A random number between 1 and 100",
        ge=1,
        le=100
    )
    num2: int = Field(
        description="A different random number between 1 and 100",
        ge=1,
        le=100
    )
    num3: int = Field(
        description="Another different random number between 1 and 100",
        ge=1,
        le=100
    )

    @field_validator('num2')
    def num2_must_be_different(cls, v, values):
        if 'num1' in values and v == values['num1']:
            raise ValueError('num2 must be different from num1')
        return v

    @field_validator('num3')
    def num3_must_be_different(cls, v, values):
        if v in [values.get('num1'), values.get('num2')]:
            raise ValueError('num3 must be different from num1 and num2')
        return v

class MajorCities(BaseModel):
    """Structured format for major cities"""
    city1: str = Field(
        description="Name of a major global city, preferably one of the top 10 by population",
        min_length=2,
        max_length=50
    )
    city2: str = Field(
        description="Name of a different major global city, not repeating the first city",
        min_length=2,
        max_length=50
    )
    city3: str = Field(
        description="Name of another different major global city, not repeating previous cities",
        min_length=2,
        max_length=50
    )

    @field_validator('city2')
    def city2_must_be_different(cls, v, values):
        if 'city1' in values and v.lower() == values['city1'].lower():
            raise ValueError('city2 must be different from city1')
        return v

    @field_validator('city3')
    def city3_must_be_different(cls, v, values):
        if v.lower() in [values.get('city1', '').lower(), values.get('city2', '').lower()]:
            raise ValueError('city3 must be different from city1 and city2')
        return v

class NonDeterminismExperiment:
    def __init__(self, num_iterations: int = 20):
        # Basic configuration
        self.num_iterations = num_iterations

        # Initialize the model
        self.model = ChatOpenAI(
            api_key=os.getenv("OPENAI_API_KEY"),
            base_url=os.getenv("BASE_URL"),
            model=os.getenv("model"),
            temperature=1.0
        )

        # Initialize results tracking
        self.raw_results = defaultdict(list)  # Store ExperimentResult objects
        self.error_counts = defaultdict(lambda: defaultdict(int))

        # Create parsers for each model
        self.exercise_parser = PydanticOutputParser(pydantic_object=ExerciseBenefits)
        self.numbers_parser = PydanticOutputParser(pydantic_object=RandomNumbers)
        self.cities_parser = PydanticOutputParser(pydantic_object=MajorCities)

        # Create prompts for each experiment with more explicit instructions
        self.exercise_prompt = PromptTemplate(
            template="Provide three distinct benefits of exercise: one physical, one mental, and one lifestyle/energy-related benefit. Ensure the mental health benefit explicitly mentions mental health aspects. Respond ONLY with the JSON format specified.\n{format_instructions}\n",
            input_variables=[],
            partial_variables={"format_instructions": self.exercise_parser.get_format_instructions()}
        )

        self.numbers_prompt = PromptTemplate(
            template="Respond ONLY with a JSON object containing three different random numbers between 1 and 100. Do not include any explanation, code, or additional text.\n{format_instructions}\n",
            input_variables=[],
            partial_variables={"format_instructions": self.numbers_parser.get_format_instructions()}
        )

        self.cities_prompt = PromptTemplate(
            template="Respond ONLY with a JSON object containing three different major global cities, preferably from the top 10 by population. Do not include any explanation or additional text.\n{format_instructions}\n",
            input_variables=[],
            partial_variables={"format_instructions": self.cities_parser.get_format_instructions()}
        )
        # Create prompts for each experiment
        # self.exercise_prompt = PromptTemplate(
        #     template="Provide three distinct benefits of exercise: one physical, one mental, and one lifestyle/energy-related benefit. Ensure the mental health benefit explicitly mentions mental health aspects.\n{format_instructions}\n",
        #     input_variables=[],
        #     partial_variables={"format_instructions": self.exercise_parser.get_format_instructions()}
        # )

        # self.numbers_prompt = PromptTemplate(
        #     template="Generate three different random numbers between 1 and 100. Each number must be unique.\n{format_instructions}\n",
        #     input_variables=[],
        #     partial_variables={"format_instructions": self.numbers_parser.get_format_instructions()}
        # )

        # self.cities_prompt = PromptTemplate(
        #     template="Name three different major global cities, preferably from the top 10 by population. Do not repeat any cities.\n{format_instructions}\n",
        #     input_variables=[],
        #     partial_variables={"format_instructions": self.cities_parser.get_format_instructions()}
        # )

    def record_result(self, experiment_type: str, success: bool, data: dict = None,
                     error_type: str = None, error_detail: str = None, raw_response: str = None):
        """Record a single experiment result"""
        result = ExperimentResult(
            success=success,
            data=data,
            error_type=error_type,
            error_detail=error_detail,
            raw_response=raw_response
        )
        self.raw_results[experiment_type].append(result)

        if not success:
            self.error_counts[experiment_type][error_type] += 1

    def run_experiment(self):
        """Run all three experiments"""
        print("Running Exercise Benefits experiment...")
        for i in range(self.num_iterations):
            print(f"Iteration {i+1}/{self.num_iterations}", end="\r")
            try:
                response = self.model.invoke(self.exercise_prompt.format())
                parsed = self.exercise_parser.parse(response.content)
                self.record_result("exercise", True, parsed.model_dump(), raw_response=response.content)
            except ValidationError as e:
                print(f"\nValidation error in exercise experiment: {e}")
                self.record_result("exercise", False,
                                error_type="validation_error",
                                error_detail=str(e),
                                raw_response=response.content if 'response' in locals() else None)
            except Exception as e:
                print(f"\nError in exercise experiment: {e}")
                self.record_result("exercise", False,
                                error_type="other_error",
                                error_detail=str(e),
                                raw_response=response.content if 'response' in locals() else None)

        print("\nRunning Random Numbers experiment...")
        for i in range(self.num_iterations):
            print(f"Iteration {i+1}/{self.num_iterations}", end="\r")
            try:
                response = self.model.invoke(self.numbers_prompt.format())
                parsed = self.numbers_parser.parse(response.content)
                self.record_result("numbers", True, parsed.model_dump(), raw_response=response.content)
            except ValidationError as e:
                print(f"\nValidation error in numbers experiment: {e}")
                self.record_result("numbers", False,
                                error_type="validation_error",
                                error_detail=str(e),
                                raw_response=response.content if 'response' in locals() else None)
            except Exception as e:
                print(f"\nError in numbers experiment: {e}")
                self.record_result("numbers", False,
                                error_type="other_error",
                                error_detail=str(e),
                                raw_response=response.content if 'response' in locals() else None)

        print("\nRunning Major Cities experiment...")
        for i in range(self.num_iterations):
            print(f"Iteration {i+1}/{self.num_iterations}", end="\r")
            try:
                response = self.model.invoke(self.cities_prompt.format())
                parsed = self.cities_parser.parse(response.content)
                self.record_result("cities", True, parsed.model_dump(), raw_response=response.content)
            except ValidationError as e:
                print(f"\nValidation error in cities experiment: {e}")
                self.record_result("cities", False,
                                error_type="validation_error",
                                error_detail=str(e),
                                raw_response=response.content if 'response' in locals() else None)
            except Exception as e:
                print(f"\nError in cities experiment: {e}")
                self.record_result("cities", False,
                                error_type="other_error",
                                error_detail=str(e),
                                raw_response=response.content if 'response' in locals() else None)


    def analyze_results(self) -> Dict:
        """Analyze the results and compute statistics"""
        analysis = {}

        for experiment_type, results in self.raw_results.items():
            successful_results = [r.data for r in results if r.success]

            prompt_analysis = {
                "total_attempts": len(results),
                "successful_responses": len(successful_results),
                "error_rate": (len(results) - len(successful_results)) / len(results),
                "error_counts": dict(self.error_counts[experiment_type]),
                "unique_responses": len(set(str(r.data) for r in results if r.success)),
                "field_analysis": {}
            }

            if successful_results:
                # Analyze variation in each field for successful responses
                all_fields = successful_results[0].keys()
                for field in all_fields:
                    values = [r[field] for r in successful_results]
                    unique_values = list(set(values))

                    field_stats = {
                        "unique_values": len(unique_values),
                        "value_frequencies": {str(val): values.count(val) for val in unique_values},
                        "entropy": entropy([values.count(val)/len(values) for val in unique_values])
                    }
                    prompt_analysis["field_analysis"][field] = field_stats

            analysis[experiment_type] = prompt_analysis

        return analysis

    def generate_report(self, analysis: Dict, output_file: Path):
        """Generate a human-readable summary report"""
        with open(output_file, "w") as f:
            f.write("Structured Output Non-Determinism Experiment Summary\n")
            f.write("===============================================\n\n")

            for experiment_type, results in analysis.items():
                f.write(f"Experiment: {experiment_type}\n")
                f.write(f"Total attempts: {results['total_attempts']}\n")
                f.write(f"Successful responses: {results['successful_responses']}\n")
                f.write(f"Error rate: {results['error_rate']:.2%}\n")

                if results['error_counts']:
                    f.write("\nError Analysis:\n")
                    for error_type, count in results['error_counts'].items():
                        f.write(f"  {error_type}: {count} occurrences\n")

                f.write(f"\nUnique successful responses: {results['unique_responses']}\n")

                if results['field_analysis']:
                    f.write("\nField Analysis:\n")
                    for field, stats in results['field_analysis'].items():
                        f.write(f"\n{field}:\n")
                        f.write(f"  Unique values: {stats['unique_values']}\n")
                        f.write(f"  Entropy: {stats['entropy']:.3f}\n")
                        f.write("  Value frequencies:\n")
                        for val, freq in stats['value_frequencies'].items():
                            f.write(f"    {val}: {freq}\n")
                f.write("\n" + "="*50 + "\n")

    def save_results(self, output_dir: str = "experiment_results"):
        """Save raw results and analysis to files"""
        timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        output_path = Path(output_dir) / timestamp
        output_path.mkdir(parents=True, exist_ok=True)

        # Save raw results including errors
        raw_results_dict = {
            exp_type: [r.model_dump() for r in results]
            for exp_type, results in self.raw_results.items()
        }
        with open(output_path / "raw_results.json", "w") as f:
            json.dump(raw_results_dict, f, indent=2, default=str)

        # Save error counts
        with open(output_path / "error_counts.json", "w") as f:
            json.dump(dict(self.error_counts), f, indent=2)

        # Save analysis
        analysis = self.analyze_results()
        with open(output_path / "analysis.json", "w") as f:
            json.dump(analysis, f, indent=2)

        # Generate summary report
        self.generate_report(analysis, output_path / "summary_report.txt")

        return output_path

# %%
# Second cell: Run the experiment
experiment = run_notebook_experiment()
# Out:
# Running Exercise Benefits experiment...
# Iteration 1/20
# Error in exercise experiment: Failed to parse ExerciseBenefits from completion {"benefit1": "Improved cardiovascular health, increasing overall physical fitness and reducing the risk of heart disease.", "benefit2": "Exercise has been shown to reduce symptoms of anxiety and depression, improve mood, and enhance overall mental well-being by promoting the release of endorphins, also known as 'feel-good' hormones, and reducing stress levels.", "benefit3": "Regular exercise can increase energy levels and reduce fatigue by improving circulation, boosting metabolic rate, and enhancing sleep quality."}. Got: 1 validation error for ExerciseBenefits
# benefit2
#   String should have at most 200 characters [type=string_too_long, input_value="Exercise has been shown ...reducing stress levels.", input_type=str]
#     For further information visit https://errors.pydantic.dev/2.9/v/string_too_long
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Error in exercise experiment: Failed to parse ExerciseBenefits from completion {"benefit1": "Regular exercise can lower the risk of developing type 2 diabetes as it improves insulin sensitivity, boosting glucose metabolism.", "benefit2": "Consistent physical activity has been shown to reduce symptoms of anxiety and depression by releasing endorphins, also known as 'feel-good' hormones, which improve mood, reduce stress levels, and promote emotional well-being.", "benefit3": "Exercising regularly can increase energy levels and reduce fatigue as it improves the body's ability to transport oxygen and nutrients to cells, enhancing overall physical performance and vitality."}. Got: 1 validation error for ExerciseBenefits
# benefit2
#   String should have at most 200 characters [type=string_too_long, input_value="Consistent physical acti...e emotional well-being.", input_type=str]
#     For further information visit https://errors.pydantic.dev/2.9/v/string_too_long
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Error in exercise experiment: Failed to parse ExerciseBenefits from completion {"benefit1": "Regular exercise can improve cardiovascular health by strengthening the heart and increasing blood flow.", "benefit2": "Exercise has been shown to reduce symptoms of anxiety and depression by releasing endorphins, also known as 'feel-good' hormones.", "benefit3": "Regular physical activity can increase energy levels and reduce fatigue, allowing for more productive daily routines and a better work-life balance."}. Got: 1 validation error for ExerciseBenefits
# benefit2
#   Value error, benefit2 must mention mental health [type=value_error, input_value="Exercise has been shown ...s 'feel-good' hormones.", input_type=str]
#     For further information visit https://errors.pydantic.dev/2.9/v/value_error
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Error in exercise experiment: Failed to parse ExerciseBenefits from completion {"benefit1": "Regular exercise strengthens the cardiovascular system, reducing the risk of heart disease and improving overall physical function by enhancing muscle and bone density.", "benefit2": "Exercise stimulates the production of neurotransmitters and hormones that promote improved mood and reduced stress, contributing to enhanced mental health and resilience against mental health conditions.", "benefit3": "Consistent physical activity improves energy levels and endurance, making daily tasks and responsibilities more manageable, and often aiding in better sleep quality."}. Got: 1 validation error for ExerciseBenefits
# benefit2
#   String should have at most 200 characters [type=string_too_long, input_value='Exercise stimulates the ...ntal health conditions.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.9/v/string_too_long
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Error in exercise experiment: Failed to parse ExerciseBenefits from completion {"benefit1": "Regular exercise can increase muscle mass and bone density, reducing the risk of osteoporosis and fractures.", "benefit2": "Exercise has been shown to reduce symptoms of depression and anxiety by releasing endorphins, also known as 'feel-good' hormones, and improving mood regulation.", "benefit3": "Regular physical activity can increase energy levels and reduce fatigue, making it easier to tackle daily tasks and responsibilities."}. Got: 1 validation error for ExerciseBenefits
# benefit2
#   Value error, benefit2 must mention mental health [type=value_error, input_value="Exercise has been shown ...roving mood regulation.", input_type=str]
#     For further information visit https://errors.pydantic.dev/2.9/v/value_error
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Error in exercise experiment: Failed to parse ExerciseBenefits from completion {"benefit1": "Improved cardiovascular health, reducing the risk of heart disease and stroke", "benefit2": "Exercise has been shown to help alleviate symptoms of anxiety and depression, and can also improve sleep quality and duration.", "benefit3": "Regular exercise can increase energy levels and reduce fatigue, helping individuals feel more motivated and productive throughout the day"}. Got: 1 validation error for ExerciseBenefits
# benefit2
#   Value error, benefit2 must mention mental health [type=value_error, input_value='Exercise has been shown ...p quality and duration.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.9/v/value_error
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Error in exercise experiment: Failed to parse ExerciseBenefits from completion {"benefit1": "Regular exercise can lower your blood pressure and reduce the risk of heart disease, improving circulation and increasing overall physical fitness.", "benefit2": "Exercise has been shown to reduce symptoms of anxiety and depression by releasing endorphins, also known as \"feel-good\" hormones, and improving self-esteem.", "benefit3": "Engaging in regular physical activity can boost energy levels and reduce fatigue, allowing you to tackle daily tasks and responsibilities with renewed vigor and enthusiasm."}. Got: 1 validation error for ExerciseBenefits
# benefit2
#   Value error, benefit2 must mention mental health [type=value_error, input_value='Exercise has been shown ... improving self-esteem.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.9/v/value_error
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
#
# Running Random Numbers experiment...
#
# Error in numbers experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in numbers experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in numbers experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in numbers experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in numbers experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in numbers experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in numbers experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in numbers experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in numbers experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in numbers experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in numbers experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in numbers experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in numbers experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in numbers experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in numbers experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in numbers experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in numbers experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in numbers experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in numbers experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in numbers experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Running Major Cities experiment...
#
# Error in cities experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in cities experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in cities experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in cities experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in cities experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in cities experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in cities experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in cities experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in cities experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in cities experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in cities experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in cities experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in cities experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in cities experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in cities experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in cities experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in cities experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in cities experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in cities experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
#
# Error in cities experiment: argument of type 'pydantic_core._pydantic_core.ValidationInfo' is not iterable
# Structured Output Non-Determinism Experiment Summary
# ===============================================
#
# Experiment: exercise
# Total attempts: 20
# Successful responses: 13
# Error rate: 35.00%
#
# Error Analysis:
#   other_error: 7 occurrences
#
# Unique successful responses: 13
#
# Field Analysis:
#
# benefit1:
#   Unique values: 13
#   Entropy: 2.565
#   Value frequencies:
#     Regular exercise can help maintain a healthy weight and reduce the risk of obesity-related diseases.: 1
#     Exercise can improve cardiovascular health by strengthening the heart and lungs, increasing stamina, and reducing the risk of heart disease.: 1
#     Regular aerobic exercise can lower resting blood pressure and reduce the risk of heart disease.: 1
#     Regular exercise can lower blood pressure and reduce the risk of heart disease by strengthening the heart and improving circulation.: 1
#     Exercise reduces blood pressure and risk of heart disease, strengthening the cardiovascular system.: 1
#     Regular exercise can lower blood pressure, reduce the risk of heart disease, and improve overall cardiovascular health.: 1
#     Regular exercise can improve cardiovascular health by reducing the risk of heart disease and lowering blood pressure.: 1
#     Exercise helps maintain a healthy weight by burning calories and building muscle mass.: 1
#     Reduces the risk of chronic diseases such as heart disease, diabetes, and certain types of cancer by strengthening the cardiovascular system and improving insulin sensitivity: 1
#     Regular exercise helps to strengthen your cardiovascular system, improving circulation and lowering the risk of heart disease.: 1
#     Exercise can help reduce obesity and lower the risk of chronic diseases, such as diabetes and heart disease.: 1
#     Regular exercise can help you maintain a healthy weight and reduce the risk of chronic diseases such as diabetes, cardiovascular disease, and certain types of cancer.: 1
#     Regular exercise can improve cardiovascular health by strengthening the heart and lungs, reducing the risk of heart disease, and increasing overall physical fitness.: 1
#
# benefit2:
#   Unique values: 12
#   Entropy: 2.458
#   Value frequencies:
#     Exercise reduces symptoms of anxiety and depression, improves mood, and enhances cognitive function, promoting better mental health.: 1
#     Exercise has been shown to reduce symptoms of anxiety and depression by promoting the release of endorphins, which can help improve mood and overall mental health.: 1
#     Regular exercise has been shown to have a positive impact on mental health, reducing symptoms of anxiety and depression, improving mood, and enhancing overall mental well-being.: 1
#     Regular physical activity has been shown to reduce symptoms of anxiety and depression, as well as improve overall mental health by releasing endorphins, also known as 'feel-good' hormones.: 1
#     Exercise has been shown to have a positive impact on mental health by reducing symptoms of anxiety and depression, improving mood, and enhancing cognitive function.: 2
#     Reduces symptoms of anxiety and depression by releasing endorphins, improving mood, and enhancing cognitive function, thereby promoting mental health and well-being: 1
#     Regular physical activity has been shown to have a positive impact on mental health, reducing symptoms of anxiety and depression, and improving mood, self-esteem, and overall sense of well-being.: 1
#     Exercise has been shown to have a positive impact on mental health, reducing symptoms of anxiety and depression, and improving mood.: 1
#     Regular exercise can help alleviate symptoms of anxiety and depression by releasing endorphins and improving mood regulation, promoting better mental health and overall well-being.: 1
#     Exercise has been shown to have a positive impact on mental health, reducing symptoms of anxiety and depression by releasing endorphins, also known as 'feel-good' hormones.: 1
#     Exercise has been shown to have a positive impact on mental health, reducing symptoms of anxiety and depression by releasing endorphins and improving mood.: 1
#     Exercise has been shown to have a positive impact on mental health, reducing symptoms of anxiety and depression, and improving mood and overall mental well-being.: 1
#
# benefit3:
#   Unique values: 13
#   Entropy: 2.565
#   Value frequencies:
#     Incorporating physical activity into your daily routine can increase energy levels and reduce fatigue, allowing you to tackle daily tasks more efficiently and effectively.: 1
#     Engaging in regular physical activity can increase energy levels and reduce fatigue, allowing for more productivity and a better overall quality of life.: 1
#     Exercise increases energy levels, allowing for more productivity and better work-life balance, and even improves sleep quality.: 1
#     Exercise can increase energy levels and reduce fatigue by improving sleep quality, increasing the release of energizing hormones like endorphins, and boosting productivity and motivation.: 1
#     Engaging in regular physical activity can increase energy levels and reduce fatigue, allowing you to tackle daily tasks with more enthusiasm and productivity.: 1
#     Provides a natural energy boost and improves sleep quality by regulating bodily rhythms, leading to increased energy levels and enhanced overall quality of life: 1
#     Exercise can increase energy levels and reduce fatigue by improving sleep quality, reducing stress, and boosting metabolism.: 1
#     Exercise can increase energy levels by strengthening the body's cardiovascular system and reducing fatigue, allowing individuals to tackle daily tasks with more vigor and enthusiasm.: 1
#     Exercise can increase energy levels and reduce fatigue by improving sleep, boosting the immune system, and releasing endorphins, also known as "feel-good" hormones.: 1
#     Engaging in regular physical activity can boost energy levels and reduce fatigue, making it easier to tackle daily tasks and activities.: 1
#     Engaging in regular physical activity can increase energy levels and reduce fatigue, allowing individuals to tackle daily tasks and responsibilities with more vitality and enthusiasm.: 1
#     Engaging in regular physical activity can increase energy levels and reduce fatigue, allowing for more productive days and improved overall quality of life.: 1
#     Exercise can increase energy levels and boost productivity, allowing individuals to tackle daily tasks and maintain a healthy work-life balance.: 1
#
# ==================================================
# Experiment: numbers
# Total attempts: 20
# Successful responses: 0
# Error rate: 100.00%
#
# Error Analysis:
#   other_error: 20 occurrences
#
# Unique successful responses: 0
#
# ==================================================
# Experiment: cities
# Total attempts: 20
# Successful responses: 0
# Error rate: 100.00%
#
# Error Analysis:
#   other_error: 20 occurrences
#
# Unique successful responses: 0
#
# ==================================================
