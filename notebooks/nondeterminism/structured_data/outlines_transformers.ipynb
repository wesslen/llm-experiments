# %% [markdown]
# <a href="https://colab.research.google.com/github/wesslen/llm-experiments/blob/main/notebooks/nondeterminism/structured_data/outlines_transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !uv pip install --system "outlines[transformers]"
# Out:
# Using Python 3.10.12 environment at /usr
# Resolved 60 packages in 1.22s
# ⠙ Preparing packages... (0/12)
# ⠙ Preparing packages... (0/12)
# ⠙ Preparing packages... (0/12)
# dill       ------------------------------ 14.93 KiB/113.53 KiB
# ⠙ Preparing packages... (0/12)
# dill       ------------------------------ 30.93 KiB/113.53 KiB
# ⠙ Preparing packages... (0/12)
# dill       ------------------------------ 46.93 KiB/113.53 KiB
# ⠙ Preparing packages... (0/12)
# dill       ------------------------------ 62.93 KiB/113.53 KiB
# ⠙ Preparing packages... (0/12)
# dill       ------------------------------ 78.93 KiB/113.53 KiB
# ⠙ Preparing packages... (0/12)
# dill       ------------------------------ 78.93 KiB/113.53 KiB
# multiprocess ------------------------------     0 B/131.66 KiB
# ⠙ Preparing packages... (0/12)
# dill       ------------------------------ 94.93 KiB/113.53 KiB
# multiprocess ------------------------------     0 B/131.66 KiB
# ⠙ Preparing packages... (0/12)
# dill       ------------------------------ 110.93 KiB/113.53 KiB
# multiprocess ------------------------------     0 B/131.66 KiB
# ⠙ Preparing packages... (0/12)
# dill       ------------------------------ 113.53 KiB/113.53 KiB
# multiprocess ------------------------------     0 B/131.66 KiB
# ⠙ Preparing packages... (0/12)
# dill       ------------------------------ 113.53 KiB/113.53 KiB
# multiprocess ------------------------------     0 B/131.66 KiB
# xxhash     ------------------------------     0 B/189.60 KiB
# ⠙ Preparing packages... (0/12)
# dill       ------------------------------ 113.53 KiB/113.53 KiB
# multiprocess ------------------------------     0 B/131.66 KiB
# xxhash     ------------------------------     0 B/189.60 KiB
# airportsdata ------------------------------     0 B/891.29 KiB
# ⠙ Preparing packages... (0/12)
# multiprocess ------------------------------     0 B/131.66 KiB
# xxhash     ------------------------------     0 B/189.60 KiB
# airportsdata ------------------------------     0 B/891.29 KiB
# ⠙ Preparing packages... (0/12)
# multiprocess ------------------------------ 16.00 KiB/131.66 KiB
# xxhash     ------------------------------     0 B/189.60 KiB
# airportsdata ------------------------------     0 B/891.29 KiB
# ⠙ Preparing packages... (0/12)
# multiprocess ------------------------------ 16.00 KiB/131.66 KiB
# xxhash     ------------------------------     0 B/189.60 KiB
# airportsdata ------------------------------     0 B/891.29 KiB
# ⠙ Preparing packages... (0/12)
# multiprocess ------------------------------ 16.00 KiB/131.66 KiB
# xxhash     ------------------------------     0 B/189.60 KiB
# airportsdata ------------------------------ 16.00 KiB/891.29 KiB
# ⠙ Preparing packages... (0/12)
# multiprocess ------------------------------ 16.00 KiB/131.66 KiB
# xxhash     ------------------------------ 16.00 KiB/189.60 KiB
# airportsdata ------------------------------ 16.00 KiB/891.29 KiB
# ⠙ Preparing packages... (0/12)
# interegular ------------------------------ 23.08 KiB/23.08 KiB
# diskcache  ------------------------------ 32.00 KiB/44.48 KiB
# outlines   ------------------------------ 14.92 KiB/90.22 KiB
# lark       ------------------------------ 13.95 KiB/108.43 KiB
# multiprocess ------------------------------ 48.00 KiB/131.66 KiB
# fsspec     ------------------------------ 32.00 KiB/175.05 KiB
# xxhash     ------------------------------ 77.71 KiB/189.60 KiB
# outlines-core ------------------------------ 32.00 KiB/341.72 KiB
# datasets   ------------------------------ 64.00 KiB/469.29 KiB
# airportsdata ------------------------------ 56.80 KiB/891.29 KiB
# ⠙ Preparing packages... (0/12)
# diskcache  ------------------------------ 32.00 KiB/44.48 KiB
# outlines   ------------------------------ 46.92 KiB/90.22 KiB
# lark       ------------------------------ 60.37 KiB/108.43 KiB
# multiprocess ------------------------------ 48.00 KiB/131.66 KiB
# fsspec     ------------------------------ 32.00 KiB/175.05 KiB
# xxhash     ------------------------------ 77.71 KiB/189.60 KiB
# outlines-core ------------------------------ 64.00 KiB/341.72 KiB
# datasets   ------------------------------ 64.00 KiB/469.29 KiB
# airportsdata ------------------------------ 56.80 KiB/891.29 KiB
# ⠙ Preparing packages... (0/12)
# outlines   ------------------------------ 46.92 KiB/90.22 KiB
# lark       ------------------------------ 80.00 KiB/108.43 KiB
# multiprocess ------------------------------ 63.84 KiB/131.66 KiB
# fsspec     ------------------------------ 90.30 KiB/175.05 KiB
# xxhash     ------------------------------ 189.60 KiB/189.60 KiB
# outlines-core ------------------------------ 335.67 KiB/341.72 KiB
# datasets   ------------------------------ 112.00 KiB/469.29 KiB
# airportsdata ------------------------------ 891.29 KiB/891.29 KiB
# ⠙ Preparing packages... (0/12)
# outlines   ------------------------------ 46.92 KiB/90.22 KiB
# lark       ------------------------------ 80.00 KiB/108.43 KiB
# multiprocess ------------------------------ 79.84 KiB/131.66 KiB
# fsspec     ------------------------------ 103.69 KiB/175.05 KiB
# xxhash     ------------------------------ 189.60 KiB/189.60 KiB
# outlines-core ------------------------------ 335.67 KiB/341.72 KiB
# datasets   ------------------------------ 128.00 KiB/469.29 KiB
# airportsdata ------------------------------ 891.29 KiB/891.29 KiB
# ⠙ Preparing packages... (0/12)
# outlines   ------------------------------ 62.92 KiB/90.22 KiB
# lark       ------------------------------ 96.00 KiB/108.43 KiB
# multiprocess ------------------------------ 79.84 KiB/131.66 KiB
# fsspec     ------------------------------ 103.69 KiB/175.05 KiB
# outlines-core ------------------------------ 341.72 KiB/341.72 KiB
# datasets   ------------------------------ 128.00 KiB/469.29 KiB
# airportsdata ------------------------------ 891.29 KiB/891.29 KiB
# ⠙ Preparing packages... (0/12)
# outlines   ------------------------------ 78.92 KiB/90.22 KiB
# lark       ------------------------------ 96.00 KiB/108.43 KiB
# multiprocess ------------------------------ 79.84 KiB/131.66 KiB
# fsspec     ------------------------------ 122.30 KiB/175.05 KiB
# outlines-core ------------------------------ 341.72 KiB/341.72 KiB
# datasets   ------------------------------ 168.91 KiB/469.29 KiB
# ⠙ Preparing packages... (0/12)
# outlines   ------------------------------ 78.92 KiB/90.22 KiB
# lark       ------------------------------ 96.00 KiB/108.43 KiB
# multiprocess ------------------------------ 127.84 KiB/131.66 KiB
# fsspec     ------------------------------ 122.30 KiB/175.05 KiB
# datasets   ------------------------------ 219.14 KiB/469.29 KiB
# ⠙ Preparing packages... (0/12)
# outlines   ------------------------------ 78.92 KiB/90.22 KiB
# multiprocess ------------------------------ 127.84 KiB/131.66 KiB
# fsspec     ------------------------------ 154.30 KiB/175.05 KiB
# datasets   ------------------------------ 235.14 KiB/469.29 KiB
# ⠙ Preparing packages... (0/12)
# outlines   ------------------------------ 90.22 KiB/90.22 KiB
# fsspec     ------------------------------ 170.30 KiB/175.05 KiB
# datasets   ------------------------------ 235.14 KiB/469.29 KiB
# ⠙ Preparing packages... (0/12)
# fsspec     ------------------------------ 175.05 KiB/175.05 KiB
# datasets   ------------------------------ 272.00 KiB/469.29 KiB
# ⠙ Preparing packages... (0/12)
# datasets   ------------------------------ 272.00 KiB/469.29 KiB
# ⠙ Preparing packages... (0/12)
# datasets   ------------------------------ 320.00 KiB/469.29 KiB
# ⠙ Preparing packages... (0/12)
# ⠙ Preparing packages... (0/12)
# ⠹ Preparing packages... (11/12)
# ⠹ Preparing packages... (11/12)
# ⠹ Preparing packages... (11/12)
# ⠹ Preparing packages... (11/12)
# ⠸ Preparing packages... (11/12)
# Prepared 12 packages in 477ms
# Uninstalled 1 package in 7ms
# Installed 12 packages in 83ms
#  + airportsdata==20241001
#  + datasets==3.1.0
#  + dill==0.3.8
#  + diskcache==5.6.3
#  - fsspec==2024.10.0
#  + fsspec==2024.9.0
#  + interegular==0.3.3
#  + lark==1.2.2
#  + multiprocess==0.70.16
#  + outlines==0.1.8
#  + outlines-core==0.1.20
#  + pycountry==24.6.1
#  + xxhash==3.5.0

# %%
import outlines

time_regex_pattern = r"(0?[1-9]|1[0-2]):[0-5]\d\s?(am|pm)?"

model = outlines.models.transformers("microsoft/Phi-3-mini-4k-instruct", device="cuda")
generator = outlines.generate.regex(model, time_regex_pattern)

output = generator("The the best time to visit a dentist is at ")
print(output)
# 2:30 pm
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/16.5k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.67G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/3.44k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/306 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/599 [00:00<?, ?B/s]
# 8:00 am

# %%
output = generator("The the best time to visit a dentist is at ")
print(output)
# Out:
# 4:01 pm

# %%
seed = 789001

answer = generator("What is 2+2?", seed=seed)
print(answer)
# Out:
# 11:50am
